# %% [markdown]
# #Título nivel 1
# ##Título nivel 2
# ###Título nivel 3

# %% [markdown]
# #Ejercicio de ingreso
#
# ###Agenda
# 1. Inserción de bloques de texto
# 2. Inserción de títulos
# 3. Trabajando con el bloque de código

# %% [markdown]
# ##Limpieza de datos

# %% [markdown]
# Uso del comando print y el uso de comentarios

# %%
#Este es un comando para imprimir un caracter de texto
print("Hola mundo")
